# %%
import numpy as np
import pandas as pd
import matplotlib
#matplotlib.use('Agg')
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 1-2 Continuous to Continuous Relationships

# %% [markdown]
# 1. The CSV file named 'stars.csv' is read into the Pandas Dataframe `df` for you below. Using SEABORN, plot a **scatter plot** showing the relationship between the `temperature` and `luminosity` of the stars. You must use `temperature` for `x` and `luminosity` for `y`. Change the y-scale of the plot by using the `.set(yscale="log")` method. Display the plot. Then, group the data by assigning the `hue` to the `type` of star. Set the `size` of each point to the star's `radius`. Display the plot again.
#
# This will reveal a flipped version of the Hertzsprung-Russel Diagram which is commonly used to chart the life cycle of stars. According to the graph, main sequence stars...

# %%
# STARTER
df = pd.read_csv("stars.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 # STARTER
# ----> 2 df = pd.read_csv("stars.csv")
#
# File c:\newfolder\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   temperature         240 non-null    int64
#  1   luminosity          240 non-null    float64
#  2   radius              240 non-null    float64
#  3   absolute magnitude  240 non-null    float64
#  4   type                240 non-null    object
#  5   color               240 non-null    object
#  6   spectral class      240 non-null    object
# dtypes: float64(3), int64(1), object(3)
# memory usage: 13.2+ KB

# %%
sns.relplot(data=df,x='temperature',y='luminosity')

# %%
sns.relplot(data=df,x='temperature',y='luminosity').set(yscale="log")

# %%
sns.relplot(data=df,x='temperature',y='luminosity', hue='type',size='radius').set(yscale="log")

# %% [markdown]
# 2. The CSV file named 'cereal.csv' is read into the Pandas Dataframe df for you below. Using SEABORN, plot a trend plot showing the relationship between the`sugars` and `rating` of each cereal.
#
#
# According to the graph, as the amount of sugar increases, ratings tend to...

# %%
# STARTER
df = pd.read_csv("cereal.csv")

# SOLUTION

# %%
sns.lmplot(data=df,x="sugars",y="rating")
plt.show()

# %% [markdown]
# # 3-4 Categorical-Continuous Relationships

# %% [markdown]
# 3. The CSV file named `'stars.csv'` is read into the Pandas Dataframe `df` for you below. Using SEABORN, plot a **conditional KDE plot** showing the relationship between the `temperature` and `color` of the stars. You must correct for sample size bias by setting `common_norm=False`.
#
# Which color star has the widest distribution of temperatures?

# %%
# STARTER
color_palette = {'Red': 'red','Blue': 'blue','White': 'grey','Yellow': 'yellow','Orange': 'orange'}
df = pd.read_csv("stars.csv")

# SOLUTION

# %%
sns.displot(data=df, x="temperature", hue="color", kind="kde", common_norm=False)
plt.show()

# %% [markdown]
# 4. The CSV file named `'stars.csv'` is read into the Pandas Dataframe `df` for you below. Using SEABORN, plot a **point plot** showing the relationship between the `type` and `temperature` of the stars. Use `type` for `x` and`temperature` for `y`. You must change the default `errorbar` argument to a 99% confidence interval.
#
# Using the 99% confidence interval, which type stars could reasonably have a temperature of 15,000K?

# %%
# STARTER
df = pd.read_csv("stars.csv")

# %%
sns.catplot(data=df, x='type', y='temperature', kind="point", errorbar=('ci', 99), aspect=3)
