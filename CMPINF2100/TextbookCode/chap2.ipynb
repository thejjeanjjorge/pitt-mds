# %%
x = 2
if x%2 == 0:
	if x%3 == 0:
		print("Divisable by 2 and 3")
	else:
		print("Divisable by 2 and not 3")
elif x%3 == 0:
	print("Divisable by 3 and not 2")
# Out:
# Divisable by 2 and not 3

# %%
x = 11
y = 7
z = 14

# 1. Create a list of the numbers
numbers = [x, y, z]

# 2. Use a list comprehension to keep only the odd numbers
# This uses the modulo operator (%) we discussed
odds = [n for n in numbers if n % 2 != 0]

# 3. Check if we found any odd numbers and print the result
if odds:
    print("The largest odd number is:", max(odds))
else:
    print("None of the numbers are odd.")
# Out:
# The largest odd number is: 11

# %%
x = 120
ans = 0
itersLeft = x
while (itersLeft != 0):
    ans = ans + x
    itersLeft = itersLeft - 1
print(str(x) + '*' + str(x) + '=' + str(ans))
# Out:
# 120*120=14400

# %%
# Find a positive integer that is divisible by both 11 and 12
x = 1
while True:
    if x%11 == 0 and x%12 == 0:
        break
    x = x + 1
print(x, "is divisible by 11 and 12")
# Out:
# 132 is divisible by 11 and 12

# %%
import random
random.seed(2100)

for i in range(5):
    print(i, random.random())
# Out:
# 0 0.764021138054951
# 1 0.4692037101382426
# 2 0.09010549233469012
# 3 0.08980190601697957
# 4 0.5561956463771123

# %%
nums = []
for _ in range(5):
    nums.append(random.random())

nums, len(nums)
# Out:
# ([0.36690797563632527,
#   0.7840449290430325,
#   0.37956664277465757,
#   0.6333253705111195,
#   0.3605664070992006],
#  5)

# %%
nums_lc = [random.random() for _ in range(5)]
nums_lc
# Out:
# [0.7231215087463677,
#  0.07281302170746007,
#  0.6669762270729921,
#  0.4942428713031397,
#  0.7956962831040792]

# %%
def average(x):
    return sum(x) / len(x)

list_of_numbers = [random.random() for _ in range(5)]
print(list_of_numbers)

average(list_of_numbers)
# Out:
# [0.6972309683740164, 0.6530137967372368, 0.4843336405398452, 0.3443993423436348, 0.48484314907607373]
# 0.5327641794141613
