# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
x = [25, 35, 45, 55, 65]
y = [234, 283, 943, 923, 382]

# %%
fig, ax = plt.subplots(figsize=(6, 3))

plt.plot(x, y, '--b')
plt.title("This is a test")
ax.set_xlabel("Test")
ax.set_ylabel("Yet, another test")
plt.show()
